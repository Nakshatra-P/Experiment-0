# %%
# Nakshatra Parshwanath - 25070123132
# Experiment - 0

print("Nakshatra Parshwanath")
print(2)
print(2.5)
print([1,2,5])
# Out:
# Nakshatra Parshwanath
# 2
# 2.5
# [1, 2, 5]
# 2 2.5 [1, 2, 5] Nakshatra Parshwanath

# %%
print(2,2.5,[1,2,5],"Nakshatra Parshwanath")
# Out:
# 2 2.5 [1, 2, 5] Nakshatra Parshwanath

# %%
print(2,2.5,[1,2,5],"Nakshatra Parshwanath",sep="\n")
# Out:
# 2
# 2.5
# [1, 2, 5]
# Nakshatra Parshwanath

# %%
a=2
A=5

sum = a + A

print (a + A)
# Out:
# 7
